# %% [markdown]
# ## 데이터 시각화의 중요성
# ### 평균 표준편차 함정

# %%
import seaborn as sns

anscombe = sns.load_dataset("anscombe")

print(anscombe[:])
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
anscombe_1 = anscombe[0:11]
anscombe_2 = anscombe[11:22]
anscombe_3 = anscombe[22:33]
anscombe_4 = anscombe[33:44]

print(anscombe_1.mean())
print(anscombe_2.mean())
print(anscombe_3.mean())
print(anscombe_4.mean())
print("-"*50)
print(anscombe_1.std())
print(anscombe_2.std())
print(anscombe_3.std())
print(anscombe_4.std())
# Out:
# x    9.000000
# y    7.500909
# dtype: float64
# x    9.000000
# y    7.500909
# dtype: float64
# x    9.0
# y    7.5
# dtype: float64
# x    9.000000
# y    7.500909
# dtype: float64
# --------------------------------------------------
# x    3.316625
# y    2.031568
# dtype: float64
# x    3.316625
# y    2.031657
# dtype: float64
# x    3.316625
# y    2.030424
# dtype: float64
# x    3.316625
# y    2.030579
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

plt.plot(dataset_1['x'], dataset_1['y'])

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

plt.plot(dataset_1['x'], dataset_1['y'])
plt.grid()

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

plt.plot(dataset_1['x'], dataset_1['y'], 'o')
plt.grid()

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
# 그래프 제작 준비
fig = plt.figure()

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %%
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')

fig.tight_layout()

fig

# %%
fig.suptitle("Anscombe Dataset")
fig.tight_layout()
fig

# %%
tips = sns.load_dataset('tips')
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips['day'].describe()
# Out:
# count     244
# unique      4
# top       Sat
# freq       87
# Name: day, dtype: object

# %%
fig = plt.figure()

axes1 = fig.add_subplot(1,1,1) # 그래프 1개이므로 굳이 안해도 되는 부분

# %%
fig = plt.figure()

axes1 = fig.add_subplot(1,1,1) # 그래프 1개이므로 굳이 안해도 되는 부분 

axes1.hist(tips['total_bill'], bins = 'auto')
axes1.set_title("History of total bill")
axes1.set_xlabel("Frequency")
axes1.grid()

tips['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
fig = plt.figure()

axes1 = fig.add_subplot(1,1,1) # 그래프 1개이므로 굳이 안해도 되는 부분 

axes1.hist(tips['size'], bins = 'auto')
axes1.set_title("History of Size")
axes1.set_xlabel("Frequency")
axes1.grid()

tips['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
fig = plt.figure()

axes1 = fig.add_subplot(1,1,1) # 그래프 1개이므로 굳이 안해도 되는 부분 

axes1.hist(tips['day'], bins = 'auto')
axes1.set_title("History of Day")
axes1.set_xlabel("Frequency")
axes1.grid()

tips['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
set(tips['day'])
# Out:
# {'Fri', 'Sat', 'Sun', 'Thur'}

# %%
fri_count = []
for i in range(len(tips['day'])):
    if tips['day'][i] == 'Fri':
        fri_count.append(i)
        
print("fri_count : ", len(fri_count))
# Out:
# fri_count :  19

# %%
sat_count = []
for i in range(len(tips['day'])):
    if tips['day'][i] == 'Sat':
        sat_count.append(i)
        
print("sat_count : ", len(sat_count))
# Out:
# sat_count :  87

# %% [markdown]
# ## 지불 금액, 팁과의 상관관계를 산점도로 도시

# %%
scatter_plot = plt.figure()
plt.figure()

axes1 = scatter_plot.add_subplot(1,1,1) # 그래프 1개이므로 굳이 안해도 되는 부분 

axes1.scatter(tips['total_bill'],
                   tips['tip'],
                  color = 'red',
                  label = 'tip and total_bill',
                  alpha = 0.5) # 투명도를 주면 점이 모여도 확인하기 용이하다.

axes1.set_title("Scatter_Plot")
axes1.set_xlabel("Total_bill")
axes1.set_ylabel("Tip")
axes1.legend()

axes1.grid()

# %% [markdown]
# ### 40~50 달러 확대 분석

# %%
total_bill_row = []
tip_row = []

for i in range(len(tips['total_bill'])):
    if tips['total_bill'][i] >= 40:
        total_bill_row.append(tips['total_bill'][i])
    if tips['total_bill'][i] >= 40:
        tip_row.append(tips['tip'][i])
        
print("total_bill_row : ", total_bill_row)
print("tip_row : ", tip_row)
# Out:
# total_bill_row :  [48.27, 40.17, 44.3, 41.19, 48.17, 50.81, 45.35, 40.55, 43.11, 48.33]
# tip_row :  [6.73, 4.73, 2.5, 5.0, 5.0, 10.0, 3.5, 3.0, 5.0, 9.0]

# %%
plt.plot(total_bill_row, tip_row, 'o')

plt.suptitle('Tips Dataset(total_bill >= 40)')

plt.xlabel("Total_bill")
plt.ylabel("Tip")

plt.grid()

# %%
ax = sns.regplot(x=total_bill_row, y=tip_row )
ax.grid()

# %%
ax = plt.subplots()
ax = sns.regplot(x = tips['total_bill'], y = tips['tip'])

ax.set_xlabel("total_bill")
ax.set_ylabel("tip")
ax.grid()

# %% [markdown]
# ## box plot

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex']=='Female']['tip'],
               tips[tips['sex']=='Male']['tip']],
              labels = ['Female', 'Male'])
               
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')

axes1.set_title('Boxplot of Tips by sex')
plt.show()

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['day']=='Thur']['total_bill'],
               tips[tips['day']=='Fri']['total_bill'],
               tips[tips['day']=='Sat']['total_bill'],
               tips[tips['day']=='Sun']['total_bill']],
              labels = ['Thur', 'Fri', 'Sat', 'Sun'])
               
axes1.set_xlabel('Day')
axes1.set_ylabel('Total_bill')

axes1.set_title('Boxplot of Total_bill by Day')
plt.show()

# %% [markdown]
# ### 추가적인 변수를 그리는 방법(아이디어)
# - 성별을 추가적으로 반영 -> 점의 색으로 구분
# - 같이 방문한 인원의 수 -> 점의 크기

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %% [markdown]
# ## apply 메서드

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)
tips[['sex', 'sex_color']].head(8)
# Out:
#       sex sex_color
# 0  Female         0
# 1    Male         1
# 2    Male         1
# 3    Male         1
# 4  Female         0
# 5    Male         1
# 6    Male         1
# 7    Male         1

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_color
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0
# 1         10.34  1.66    Male     No   Sun  Dinner     3         1
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1
# 242       17.82  1.75    Male     No   Sat  Dinner     2         1
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0
#
# [244 rows x 8 columns]
