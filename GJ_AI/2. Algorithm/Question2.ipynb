# %% [markdown]
# ![snap212.png](attachment:snap212.png)

# %% [markdown]
# ![snap208.png](attachment:snap208.png)

# %% [markdown]
# ![snap209.png](attachment:snap209.png)

# %% [markdown]
# ![snap210.png](attachment:snap210.png)

# %% [markdown]
# ![snap211.png](attachment:snap211.png)
