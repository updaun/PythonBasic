# %% [markdown]
# ### Pandas 시각화

# %% [markdown]
# ![pandas_visualizer.png](attachment:pandas_visualizer.png)

# %%
import numpy as np # NumPy
import pandas as pd # Pandas

# IPython( jupyter notebook ) 디스플레이 설정 변경
# 출력할 열의 개수 한도 설정
pd.set_option( 'display.max_columns', 20 )
# 출력할 열의 너비 설정
pd.set_option( 'display.max_colwidth', 20 )
# 유니코드 사용 너비 조정
pd.set_option( 'display.unicode.east_asian_width', True )

# 경고( warnings ) 메시지 출력 방지
import warnings
warnings.filterwarnings( 'ignore' )

# %%
df = pd.read_excel('data/남북한발전전력량.xlsx')

# %%
df.head()
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  \
# 0           남한        합계  1077  1186  1310  1444  1650  1847  2055  2244
# 1            NaN        수력    64    51    49    60    41    55    52    54
# 2            NaN        화력   484   573   696   803  1022  1122  1264  1420
# 3            NaN      원자력   529   563   565   581   587   670   739   771
# 4            NaN      신재생     -     -     -     -     -     -     -     -
#
#    ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  ...  4031  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1  ...    50    56    56    65    78    77    84    78    58    66
# 2  ...  2551  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  ...  1429  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 4  ...     -     -     -     -     -    86   118   151   173   195
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전력량 (억㎾h)  2 non-null      object
#  1   발전 전력별     9 non-null      object
#  2   1990       9 non-null      object
#  3   1991       9 non-null      object
#  4   1992       9 non-null      object
#  5   1993       9 non-null      object
#  6   1994       9 non-null      object
#  7   1995       9 non-null      object
#  8   1996       9 non-null      object
#  9   1997       9 non-null      object
#  10  1998       9 non-null      object
#  11  1999       9 non-null      object
#  12  2000       9 non-null      object
#  13  2001       9 non-null      object
#  14  2002       9 non-null      object
#  15  2003       9 non-null      object
#  16  2004       9 non-null      object
#  17  2005       9 non-null      object
#  18  2006       9 non-null      object
# ...

# %%
df_ns = df.iloc[ [ 0, 5 ], 3: ] # 남북한 발전량 합계만 추출
df_ns.index = [ 'South', 'North' ] # 인덱스 이름 설정
df_ns.columns = df_ns.columns.map( int ) # 열 이름의 자료형을 int로 변환
df_ns.head()
# Out:
#        1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2007  \
# South  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664  ...  4031
# North   263   247   221   231   230   213   193   170   186   194  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 26 columns]

# %%
df_ns.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\projects\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-0a0f32c6f41e> in <module>
# ----> 1 df_ns.info()
#
# ...

# %%
# matplotlib 사용시 한글 폰트 출력 오류 문제 해결 - windows OS
from matplotlib import font_manager, rc
font_path = "c:\\Windows\\Fonts\\malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family = font_name)

# %%
# matplotlib 사용시 한글 폰트 출력 오류 문제 해결 - Mac OS
from matplotlib import rc
rc('font', family = 'AppleGothic')

# %% [markdown]
# ## 선 그래프( line plot )

# %%
df_ns.plot()
# df_ns.plot( kind = 'line' )
# Out:
# <AxesSubplot:>

# %%
tdf_ns = df_ns.T # 전치
tdf_ns.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 막대 그래프( bar plot )

# %%
tdf_ns.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
tdf_ns.plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 히스토그램 ( histogram )

# %%
tdf_ns.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## (긴)상자 수염 그래프(box plot)

# %%
df = pd.read_csv('data/auto-mpg-title.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  accelaration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                 name
# 0       1  chevrolet chevel...
# 1       1    buick skylark 320
# 2       1   plymouth satellite
# 3       1        amc rebel sst
# 4       1          ford torino

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  accelaration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df[['mpg']].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df[['mpg','cylinders']].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 산점도 ( scatter chart )

# %%
# corr() 메서드 : 상관 계수 계산 메서드
# 상관계수 : -1 ~ 1
df[['mpg','weight']].corr()
# Out:
#              mpg    weight
# mpg     1.000000 -0.831741
# weight -0.831741  1.000000

# %%
df.plot(x = 'weight', y = 'mpg', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
df[['mpg','cylinders']].corr()
# Out:
#                 mpg  cylinders
# mpg        1.000000  -0.775396
# cylinders -0.775396   1.000000

# %%
df.plot(x='cylinders', y = 'mpg', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %% [markdown]
# ## Matplotlib 시각화
# ### 선 그래프 ( line plot )

# %%
df = pd.read_excel('data/시도별 전출입 인구수.xlsx', header = 0)
df.head()
# Out:
#    전출지별    전입지별           1970           1971           1972  \
# 0  전출지별    전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1      전국        전국        4046536        4210164        3687938
# 2       NaN  서울특별시        1742813        1671705        1349333
# 3       NaN  부산광역시         448577         389797         362202
# 4       NaN  대구광역시              -              -              -
#
#             1973           1974           1975           1976           1977  \
# 0  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1        4860418        5297969        9011440        6773250        7397623
# 2        1831858        2050392        3396662        2756510        2893403
# 3         482061         680984         805979         724664         785117
# 4              -              -              -              -              -
#
#    ...           2008           2009           2010           2011  \
# 0  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# ...

# %%
df = df.fillna(method = 'ffill')

# 서울에서 다른 지역으로 전출한 데이터만 추출
mask = (df['전출지별'] == '서울특별시') & \
        (df['전입지별'] != '서울특별시')
df_seoul = df[mask]
df_seoul = df_seoul.drop(['전출지별'], axis = 1)
df_seoul.rename({'전입지별': '전입지'}, axis = 1, inplace = True)
df_seoul.set_index('전입지', inplace = True)

df_seoul.head()
# Out:
#                1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국        1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시    11568    11130    11768    16307    22220    27515    23732
# 대구광역시        -        -        -        -        -        -        -
# 인천광역시        -        -        -        -        -        -        -
# 광주광역시        -        -        -        -        -        -        -
#
#                1977     1978     1979  ...     2008     2009     2010  \
# 전입지                                 ...
# 전국        2678007  3028911  2441242  ...  2083352  1925452  1848038
# 부산광역시    27213    29856    28542  ...    17353    17738    17418
# 대구광역시        -        -        -  ...     9720    10464    10277
# 인천광역시        -        -        -  ...    50493    45392    46082
# 광주광역시        -        -        -  ...    10846    11725    11095
#
#                2011     2012     2013     2014     2015     2016     2017
# 전입지
# ...

# %%
sr_one = df_seoul.loc['경기도']
sr_one.head()
# Out:
# 1970    130149
# 1971    150313
# 1972     93333
# 1973    143234
# 1974    149045
# Name: 경기도, dtype: object

# %%
# matplotlib import
import matplotlib.pyplot as plt

# IPython 매직 명령 : 그래프를 jupyter notebook에 포함
# %matplotlib inline

# %%
# matplotlib 그래프 작성 함수 : matplotlib.plot()
plt.plot(sr_one.index, sr_one.values)

# %%
plt.plot(sr_one)

# %% [markdown]
# ## 그래프 꾸미기

# %%
# 그래프 표시
plt.plot( sr_one.index, sr_one.values)

# 그래프 제목
plt.title('서울 -> 경기 인구 이동')

# x, y축 이름
plt.xlabel('기간')
plt.ylabel('이동 인구수')

# 변경 사항을 저장하고 그래프에 반영
plt.show()

# %%
# figsize = (14, 8) : 그래프 크기 결정(가로 : 14인치, 세로 : 5인치)
plt.figure(figsize = (14,5))

# plt.xticks(rotation = 'vertical')
plt.xticks(rotation = 50)

plt.plot(sr_one.index, sr_one.values)

plt.title('서울 -> 경기 인구 이동')
plt.xlabel('기간')
plt.ylabel('이동 인구수')
plt.legend(labels = ['서울 -> 경기'], loc = 'best')

plt.show()

# %%
plt.style.use('ggplot')

# figsize = (14, 8) : 그래프 크기 결정( 가로 : 14인치, 세로 : 5인치)
plt.figure(figsize = (14,5))

# plt.xticks( rotation = 'vertical')
plt.xticks(rotation = 50)

plt.plot(sr_one.index, sr_one.values,
        marker = 'o', markersize = 10)

plt.title('서울 -> 경기 인구 이동')
plt.xlabel('기간')
plt.ylabel('이동 인구수')
plt.legend(labels = ['서울 -> 경기'], loc = 'best')

plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('ggplot')
plt.figure( figsize = (14, 5))
plt.xticks( size = 10, rotation = 90)
plt.plot(sr_one.index, sr_one.values, marker='o', markersize = 10)
plt.title('서울 -> 경기 인구 이동')
plt.xlabel('기간')
plt.ylabel('인구 이동수')

plt.legend(labels = ['서울 -> 경기'], loc = 'best' )

plt.ylim(50000, 800000)

# 화살표 표시
plt.annotate('', xy = (20,620000), xytext = (2, 290000),
             xycoords = 'data',
             arrowprops = dict( arrowstyle = '->',
                              color = 'skyblue', lw = 5))
plt.annotate('', xy = (47,450000), xytext = (30, 580000),
             xycoords = 'data',
             arrowprops = dict( arrowstyle = '->',
                              color = 'olive', lw = 5))    
             
# 텍스트 표시
plt.annotate('인구 이동 증가(1970 - 1995)',
            xy = (10, 350000), rotation = 25, va = 'baseline',
            ha = 'center', fontsize = 15)
plt.annotate('인구 이동 감수(1995 - 2017)',
            xy = (40, 560000), rotation =  11, va = 'baseline',
            ha = 'center', fontsize = 15)
             
plt.show()
